# %%
from dotenv import load_dotenv
import os
import requests
from typing import *
import sys
import subprocess
import shlex
from datetime import datetime
import json
import uuid
import pandas as pd
from google.cloud import storage

# Add path to import custom modules
# sys.path.append(os.path.abspath("../src"))

load_dotenv()
# Out:
# True

# %%
# TEMP_DIR = "./temp/"
# RAW_DIR = os.path.join(TEMP_DIR,"raw")
# PQ_DIR = os.path.join(TEMP_DIR,"pq")

# temp_dirs = [RAW_DIR,PQ_DIR]

# for dir in temp_dirs:
#     os.makedirs(dir,exist_ok=True)

# %%
# result = subprocess.Popen(f"rm -rvf {TEMP_DIR}",shell=True,text=True)
# result
# Out:
# <Popen: returncode: None args: 'rm -rvf ./temp/'>
# removed directory './temp/raw'
# removed directory './temp/pq'
# removed directory './temp/'

# %%
# logger_config.py
import logging

def configure_logging():
    # Configure the root logger
    root_logger = logging.getLogger()
    
    # Check if handlers already exist to avoid duplicates
    if root_logger.handlers:
        return
        
    # Create a stream handler for console output
    console_handler = logging.StreamHandler()
    console_handler.setLevel(logging.INFO)
    
    # Create formatter and add to the handler
    formatter = logging.Formatter('[%(asctime)s] %(name)s:%(lineno)d - %(levelname)s - %(message)s')
    console_handler.setFormatter(formatter)
    
    # Add the handler to the root logger
    root_logger.addHandler(console_handler)
    root_logger.setLevel(logging.INFO)

def get_module_logger(module_name):
    # Make sure logging is configured
    configure_logging()
    
    # Return a logger with the module name
    return logging.getLogger(module_name)

# %%
# BASE_URL = "https://api.fda.gov/drug/event.json"

# skip = 0 # upto 25000

# # Fetch data from the FDA API
# params = {
#     "api_key": os.getenv("OPENFDA_API_KEY"),
#     "limit": 1000,
#     "skip": skip
# }

# response = requests.get(BASE_URL, params=params)
# data = response.json()
# data

# %% [markdown]
# Flow:
# - Download the .json.zip files to a temporary directory.
# - Unzip them to a temporary directory.
# - Process the JSON data into Parquet.
# - Upload the Parquet files to GCS.
# - Delete the temporary files after processing.
# - Perform this for each batch

# %%
# Link to downloads of Drug Event data
res = requests.get("https://api.fda.gov/download.json")
data = res.json()
# sum([float(p.get('size_mb')) for p in data.get('results').get('drug').get('event').get('partitions')])
# data.get('results').get('drug').get('event').get('partitions')[0]
data
# Out:
# {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.',
#   'terms': 'https://open.fda.gov/terms/',
#   'license': 'https://open.fda.gov/license/',
#   'last_updated': '2025-05-03'},
#  'results': {'food': {'enforcement': {'export_date': '2025-04-28',
#     'partitions': [{'display_name': '/food/enforcement data',
#       'file': 'https://download.open.fda.gov/food/enforcement/food-enforcement-0001-of-0001.json.zip',
#       'size_mb': '5.15',
#       'records': 27219}],
#     'total_records': 27219},
#    'event': {'export_date': '2025-04-28',
#     'partitions': [{'display_name': '/food/event data',
#       'file': 'https://download.open.fda.gov/food/event/food-event-0001-of-0001.json.zip',
#       'size_mb': '7.99',
#       'records': 140565}],
#     'total_records': 140565}},
#   'animalandveterinary': {'event': {'export_date': '2025-04-28',
#     'partitions': [{'display_name': '2004 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2004q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.68',
#       'records': 5996},
#      {'display_name': '1994 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1994q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.06',
#       'records': 552},
#      {'display_name': '1997 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1997q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.12',
#       'records': 1068},
#      {'display_name': '2020 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2020q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.32',
#       'records': 18717},
#      {'display_name': '2010 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2010q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '1.05',
#       'records': 9641},
#      {'display_name': '2005 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2005q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.62',
#       'records': 5752},
#      {'display_name': '2013 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2013q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.09',
#       'records': 19605},
#      {'display_name': '2003 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2003q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.32',
#       'records': 2906},
#      {'display_name': '2008 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2008q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.88',
#       'records': 7804},
#      {'display_name': '1999 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1999q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.26',
#       'records': 2321},
#      {'display_name': '1992 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1992q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.03',
#       'records': 287},
#      {'display_name': '2014 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2014q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.43',
#       'records': 13822},
#      {'display_name': '2018 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2018q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.88',
#       'records': 15766},
#      {'display_name': '2013 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2013q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.43',
#       'records': 14845},
#      {'display_name': '2009 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2009q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.95',
#       'records': 9021},
#      {'display_name': '2011 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2011q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '1.83',
#       'records': 14122},
#      {'display_name': '1995 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1995q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.10',
#       'records': 1281},
#      {'display_name': '2009 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2009q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '1.14',
#       'records': 11199},
#      {'display_name': '2000 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2000q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.37',
#       'records': 3653},
#      {'display_name': '2023 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2023q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.18',
#       'records': 17057},
#      {'display_name': '2007 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2007q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.70',
#       'records': 6001},
#      {'display_name': '1993 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1993q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.03',
#       'records': 301},
#      {'display_name': '1997 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1997q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.12',
#       'records': 1206},
#      {'display_name': '1998 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1998q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.25',
#       'records': 2335},
#      {'display_name': '2020 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2020q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.72',
#       'records': 14990},
#      {'display_name': '1996 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1996q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.08',
#       'records': 812},
#      {'display_name': '2024 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2024q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '4.23',
#       'records': 22360},
#      {'display_name': '2005 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2005q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.55',
#       'records': 4357},
#      {'display_name': '1987 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1987q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.02',
#       'records': 211},
#      {'display_name': '2011 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2011q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '1.04',
#       'records': 9258},
#      {'display_name': '2014 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2014q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.42',
#       'records': 20055},
#      {'display_name': '1988 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1988q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.03',
#       'records': 299},
#      {'display_name': '2022 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2022q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.65',
#       'records': 15138},
#      {'display_name': '1990 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1990q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.02',
#       'records': 220},
#      {'display_name': '2012 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2012q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.83',
#       'records': 19044},
#      {'display_name': '2002 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2002q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.32',
#       'records': 2858},
#      {'display_name': '2021 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2021q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.35',
#       'records': 13183},
#      {'display_name': '1995 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1995q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.06',
#       'records': 609},
#      {'display_name': '2006 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2006q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.59',
#       'records': 4939},
#      {'display_name': '2020 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2020q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.40',
#       'records': 19296},
#      {'display_name': '2021 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2021q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.99',
#       'records': 17205},
#      {'display_name': '2024 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2024q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '4.17',
#       'records': 21421},
#      {'display_name': '2002 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2002q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.37',
#       'records': 3488},
#      {'display_name': '1995 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1995q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.06',
#       'records': 616},
#      {'display_name': '2007 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2007q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.79',
#       'records': 6654},
#      {'display_name': '1993 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1993q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.04',
#       'records': 338},
#      {'display_name': '2006 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2006q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.67',
#       'records': 5755},
#      {'display_name': '2001 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2001q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.34',
#       'records': 3185},
#      {'display_name': '2000 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2000q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.38',
#       'records': 3401},
#      {'display_name': '1988 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1988q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.03',
#       'records': 215},
#      {'display_name': '2023 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2023q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.60',
#       'records': 13872},
#      {'display_name': '1994 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1994q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.05',
#       'records': 458},
#      {'display_name': '1990 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1990q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.03',
#       'records': 235},
#      {'display_name': '2009 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2009q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '1.09',
#       'records': 10608},
#      {'display_name': '1997 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1997q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.09',
#       'records': 888},
#      {'display_name': '2004 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2004q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.60',
#       'records': 5177},
#      {'display_name': '2001 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2001q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.38',
#       'records': 3637},
#      {'display_name': '2003 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2003q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.44',
#       'records': 3797},
#      {'display_name': '1992 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1992q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.02',
#       'records': 186},
#      {'display_name': '2012 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2012q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.44',
#       'records': 15232},
#      {'display_name': '2014 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2014q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.70',
#       'records': 15302},
#      {'display_name': '2021 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2021q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.10',
#       'records': 18017},
#      {'display_name': '2017 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2017q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.91',
#       'records': 15952},
#      {'display_name': '2003 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2003q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.40',
#       'records': 3329},
#      {'display_name': '2003 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2003q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.43',
#       'records': 3644},
#      {'display_name': '2000 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2000q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.44',
#       'records': 4519},
#      {'display_name': '1994 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1994q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.04',
#       'records': 363},
#      {'display_name': '1987 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1987q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.03',
#       'records': 323},
#      {'display_name': '2000 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2000q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.62',
#       'records': 6575},
#      {'display_name': '2007 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2007q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.81',
#       'records': 7419},
#      {'display_name': '2012 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2012q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.05',
#       'records': 13540},
#      {'display_name': '1990 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1990q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.03',
#       'records': 238},
#      {'display_name': '1996 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1996q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.08',
#       'records': 845},
#      {'display_name': '2015 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2015q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.54',
#       'records': 20035},
#      {'display_name': '2004 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2004q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.51',
#       'records': 4303},
#      {'display_name': '1989 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1989q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.03',
#       'records': 265},
#      {'display_name': '2010 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2010q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.99',
#       'records': 9195},
#      {'display_name': '1999 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1999q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.46',
#       'records': 4368},
#      {'display_name': '2004 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2004q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.58',
#       'records': 4989},
#      {'display_name': '2009 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2009q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.97',
#       'records': 9160},
#      {'display_name': '1991 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1991q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.02',
#       'records': 215},
#      {'display_name': '2014 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2014q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.19',
#       'records': 18686},
#      {'display_name': '2010 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2010q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '1.19',
#       'records': 11841},
#      {'display_name': '1989 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1989q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.05',
#       'records': 444},
#      {'display_name': '1989 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1989q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.04',
#       'records': 432},
#      {'display_name': '1996 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1996q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.09',
#       'records': 900},
#      {'display_name': '2016 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2016q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.84',
#       'records': 15767},
#      {'display_name': '2005 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2005q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.61',
#       'records': 5337},
#      {'display_name': '2011 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2011q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '1.71',
#       'records': 11674},
#      {'display_name': '2011 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2011q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '1.44',
#       'records': 13931},
#      {'display_name': '2007 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2007q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.83',
#       'records': 7608},
#      {'display_name': '2008 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2008q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '1.03',
#       'records': 9444},
#      {'display_name': 'All other data (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/all_other/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.01',
#       'records': 80},
#      {'display_name': '2024 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2024q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.09',
#       'records': 15852},
#      {'display_name': '2018 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2018q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.52',
#       'records': 19640},
#      {'display_name': '2024 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2024q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.53',
#       'records': 18283},
#      {'display_name': '1992 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1992q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.03',
#       'records': 287},
#      {'display_name': '2008 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2008q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '1.13',
#       'records': 9619},
#      {'display_name': '2012 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2012q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.87',
#       'records': 18621},
#      {'display_name': '2016 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2016q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.03',
#       'records': 16399},
#      {'display_name': '2022 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2022q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.55',
#       'records': 13698},
#      {'display_name': '1991 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1991q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.03',
#       'records': 267},
#      {'display_name': '1993 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1993q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.03',
#       'records': 298},
#      {'display_name': '2019 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2019q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.80',
#       'records': 15717},
#      {'display_name': '1987 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1987q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.03',
#       'records': 260},
#      {'display_name': '1994 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1994q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.04',
#       'records': 369},
#      {'display_name': '2017 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2017q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.11',
#       'records': 16964},
#      {'display_name': '2019 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2019q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.66',
#       'records': 21400},
#      {'display_name': '2006 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2006q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.66',
#       'records': 5596},
#      {'display_name': '2016 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2016q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.60',
#       'records': 20791},
#      {'display_name': '1997 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1997q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.18',
#       'records': 1815},
#      {'display_name': '2006 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2006q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.73',
#       'records': 6441},
#      {'display_name': '1998 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1998q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.39',
#       'records': 4169},
#      {'display_name': '1998 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1998q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.19',
#       'records': 1989},
#      {'display_name': '1991 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1991q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.02',
#       'records': 231},
#      {'display_name': '2023 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2023q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.20',
#       'records': 17690},
#      {'display_name': '2022 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2022q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.01',
#       'records': 16778},
#      {'display_name': '1989 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1989q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.02',
#       'records': 199},
#      {'display_name': '2001 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2001q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.42',
#       'records': 4246},
#      {'display_name': '1991 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1991q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.02',
#       'records': 230},
#      {'display_name': '2013 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2013q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.52',
#       'records': 15348},
#      {'display_name': '2021 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2021q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.67',
#       'records': 14745},
#      {'display_name': '2018 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2018q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.83',
#       'records': 15012},
#      {'display_name': '1999 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1999q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.32',
#       'records': 2880},
#      {'display_name': '2013 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2013q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.04',
#       'records': 19539},
#      {'display_name': '1995 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1995q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.07',
#       'records': 672},
#      {'display_name': '1992 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1992q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.03',
#       'records': 263},
#      {'display_name': '2005 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2005q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.59',
#       'records': 5157},
#      {'display_name': '2023 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2023q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.17',
#       'records': 16697},
#      {'display_name': '1990 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1990q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.02',
#       'records': 188},
#      {'display_name': '2002 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2002q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.41',
#       'records': 3814},
#      {'display_name': '1998 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1998q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.12',
#       'records': 1140},
#      {'display_name': '2015 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2015q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.62',
#       'records': 14355},
#      {'display_name': '2016 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2016q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.64',
#       'records': 20948},
#      {'display_name': '1988 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1988q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.03',
#       'records': 277},
#      {'display_name': '2018 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2018q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.68',
#       'records': 20668},
#      {'display_name': '2017 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2017q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '4.01',
#       'records': 23026},
#      {'display_name': '1987 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1987q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.03',
#       'records': 299},
#      {'display_name': '2017 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2017q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.67',
#       'records': 21124},
#      {'display_name': '2008 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2008q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.83',
#       'records': 7402},
#      {'display_name': '2001 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2001q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.42',
#       'records': 4135},
#      {'display_name': '2020 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2020q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.79',
#       'records': 15350},
#      {'display_name': '2015 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2015q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.93',
#       'records': 16303},
#      {'display_name': '1999 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1999q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.22',
#       'records': 1920},
#      {'display_name': '2015 Q2 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2015q2/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.61',
#       'records': 20514},
#      {'display_name': '2022 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2022q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.41',
#       'records': 13059},
#      {'display_name': '1996 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1996q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.06',
#       'records': 618},
#      {'display_name': '1988 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1988q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.03',
#       'records': 241},
#      {'display_name': '2002 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2002q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.32',
#       'records': 2795},
#      {'display_name': '2019 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2019q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '3.45',
#       'records': 19878},
#      {'display_name': '2019 Q4 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2019q4/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '2.80',
#       'records': 15496},
#      {'display_name': '2010 Q3 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/2010q3/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '1.23',
#       'records': 12037},
#      {'display_name': '1993 Q1 (all)',
#       'file': 'https://download.open.fda.gov/animalandveterinary/event/1993q1/animalandveterinary-event-0001-of-0001.json.zip',
#       'size_mb': '0.03',
#       'records': 320}],
#     'total_records': 1262064}},
#   'tobacco': {'problem': {'export_date': '2025-05-03',
#     'partitions': [{'display_name': '/tobacco/problem data',
#       'file': 'https://download.open.fda.gov/tobacco/problem/tobacco-problem-0001-of-0001.json.zip',
#       'size_mb': '0.05',
#       'records': 1265}],
#     'total_records': 1265}},
#   'other': {'historicaldocument': {'export_date': '2025-04-25',
#     'partitions': [{'display_name': '/other/historicaldocument data',
#       'file': 'https://download.open.fda.gov/other/historicaldocument/other-historicaldocument-0001-of-0001.json.zip',
#       'size_mb': '13.23',
#       'records': 8858}],
#     'total_records': 8858},
#    'unii': {'export_date': '2025-05-03',
#     'partitions': [{'display_name': '/other/unii data',
#       'file': 'https://download.open.fda.gov/other/unii/other-unii-0001-of-0001.json.zip',
#       'size_mb': '3.24',
#       'records': 165867}],
#     'total_records': 165867},
#    'nsde': {'export_date': '2025-05-03',
#     'partitions': [{'display_name': '/other/nsde (part 1 of 3)',
#       'file': 'https://download.open.fda.gov/other/nsde/other-nsde-0001-of-0003.json.zip',
#       'size_mb': '11.34',
#       'records': 250000},
#      {'display_name': '/other/nsde (part 2 of 3)',
#       'file': 'https://download.open.fda.gov/other/nsde/other-nsde-0002-of-0003.json.zip',
#       'size_mb': '11.33',
#       'records': 250000},
#      {'display_name': '/other/nsde (part 3 of 3)',
#       'file': 'https://download.open.fda.gov/other/nsde/other-nsde-0003-of-0003.json.zip',
#       'size_mb': '5.74',
#       'records': 126688}],
#     'total_records': 626688},
#    'substance': {'export_date': '2025-04-28',
#     'partitions': [{'display_name': '/other/substance data',
#       'file': 'https://download.open.fda.gov/other/substance/other-substance-0001-of-0001.json.zip',
#       'size_mb': '307.06',
#       'records': 162731}],
#     'total_records': 162731}},
#   'device': {'classification': {'export_date': '2025-04-28',
#     'partitions': [{'display_name': '/device/classification data',
#       'file': 'https://download.open.fda.gov/device/classification/device-classification-0001-of-0001.json.zip',
#       'size_mb': '3.02',
#       'records': 6974}],
#     'total_records': 6974},
#    '510k': {'export_date': '2025-04-28',
#     'partitions': [{'display_name': '/device/510k data',
#       'file': 'https://download.open.fda.gov/device/510k/device-510k-0001-of-0001.json.zip',
#       'size_mb': '227.93',
#       'records': 171521}],
#     'total_records': 171521},
#    'covid19serology': {'export_date': '2025-05-03',
#     'partitions': [{'display_name': '/device/covid19serology data',
#       'file': 'https://download.open.fda.gov/device/covid19serology/device-covid19serology-0001-of-0001.json.zip',
#       'size_mb': '0.33',
#       'records': 13420}],
#     'total_records': 13420},
#    'registrationlisting': {'export_date': '2025-04-28',
#     'partitions': [{'display_name': '/device/registrationlisting (part 1 of 2)',
#       'file': 'https://download.open.fda.gov/device/registrationlisting/device-registrationlisting-0001-of-0002.json.zip',
#       'size_mb': '61.51',
#       'records': 250000},
#      {'display_name': '/device/registrationlisting (part 2 of 2)',
#       'file': 'https://download.open.fda.gov/device/registrationlisting/device-registrationlisting-0002-of-0002.json.zip',
#       'size_mb': '18.36',
#       'records': 74665}],
#     'total_records': 324665},
#    'enforcement': {'export_date': '2025-04-28',
#     'partitions': [{'display_name': '/device/enforcement data',
#       'file': 'https://download.open.fda.gov/device/enforcement/device-enforcement-0001-of-0001.json.zip',
#       'size_mb': '74.50',
#       'records': 35864}],
#     'total_records': 35864},
#    'udi': {'export_date': '2025-04-28',
#     'partitions': [{'display_name': '/device/udi (part 1 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0001-of-0044.json.zip',
#       'size_mb': '34.89',
#       'records': 100000},
#      {'display_name': '/device/udi (part 2 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0002-of-0044.json.zip',
#       'size_mb': '34.84',
#       'records': 100000},
#      {'display_name': '/device/udi (part 3 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0003-of-0044.json.zip',
#       'size_mb': '34.09',
#       'records': 100000},
#      {'display_name': '/device/udi (part 4 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0004-of-0044.json.zip',
#       'size_mb': '34.91',
#       'records': 100000},
#      {'display_name': '/device/udi (part 5 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0005-of-0044.json.zip',
#       'size_mb': '34.84',
#       'records': 100000},
#      {'display_name': '/device/udi (part 6 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0006-of-0044.json.zip',
#       'size_mb': '34.81',
#       'records': 100000},
#      {'display_name': '/device/udi (part 7 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0007-of-0044.json.zip',
#       'size_mb': '34.82',
#       'records': 100000},
#      {'display_name': '/device/udi (part 8 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0008-of-0044.json.zip',
#       'size_mb': '34.44',
#       'records': 100000},
#      {'display_name': '/device/udi (part 9 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0009-of-0044.json.zip',
#       'size_mb': '34.37',
#       'records': 100000},
#      {'display_name': '/device/udi (part 10 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0010-of-0044.json.zip',
#       'size_mb': '34.96',
#       'records': 100000},
#      {'display_name': '/device/udi (part 11 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0011-of-0044.json.zip',
#       'size_mb': '34.96',
#       'records': 100000},
#      {'display_name': '/device/udi (part 12 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0012-of-0044.json.zip',
#       'size_mb': '34.63',
#       'records': 100000},
#      {'display_name': '/device/udi (part 13 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0013-of-0044.json.zip',
#       'size_mb': '34.34',
#       'records': 100000},
#      {'display_name': '/device/udi (part 14 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0014-of-0044.json.zip',
#       'size_mb': '34.86',
#       'records': 100000},
#      {'display_name': '/device/udi (part 15 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0015-of-0044.json.zip',
#       'size_mb': '34.78',
#       'records': 100000},
#      {'display_name': '/device/udi (part 16 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0016-of-0044.json.zip',
#       'size_mb': '34.86',
#       'records': 100000},
#      {'display_name': '/device/udi (part 17 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0017-of-0044.json.zip',
#       'size_mb': '34.26',
#       'records': 100000},
#      {'display_name': '/device/udi (part 18 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0018-of-0044.json.zip',
#       'size_mb': '34.78',
#       'records': 100000},
#      {'display_name': '/device/udi (part 19 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0019-of-0044.json.zip',
#       'size_mb': '34.84',
#       'records': 100000},
#      {'display_name': '/device/udi (part 20 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0020-of-0044.json.zip',
#       'size_mb': '34.87',
#       'records': 100000},
#      {'display_name': '/device/udi (part 21 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0021-of-0044.json.zip',
#       'size_mb': '34.41',
#       'records': 100000},
#      {'display_name': '/device/udi (part 22 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0022-of-0044.json.zip',
#       'size_mb': '34.54',
#       'records': 100000},
#      {'display_name': '/device/udi (part 23 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0023-of-0044.json.zip',
#       'size_mb': '34.86',
#       'records': 100000},
#      {'display_name': '/device/udi (part 24 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0024-of-0044.json.zip',
#       'size_mb': '34.58',
#       'records': 100000},
#      {'display_name': '/device/udi (part 25 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0025-of-0044.json.zip',
#       'size_mb': '34.68',
#       'records': 100000},
#      {'display_name': '/device/udi (part 26 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0026-of-0044.json.zip',
#       'size_mb': '34.68',
#       'records': 100000},
#      {'display_name': '/device/udi (part 27 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0027-of-0044.json.zip',
#       'size_mb': '34.99',
#       'records': 100000},
#      {'display_name': '/device/udi (part 28 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0028-of-0044.json.zip',
#       'size_mb': '34.75',
#       'records': 100000},
#      {'display_name': '/device/udi (part 29 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0029-of-0044.json.zip',
#       'size_mb': '34.55',
#       'records': 100000},
#      {'display_name': '/device/udi (part 30 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0030-of-0044.json.zip',
#       'size_mb': '34.56',
#       'records': 100000},
#      {'display_name': '/device/udi (part 31 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0031-of-0044.json.zip',
#       'size_mb': '34.72',
#       'records': 100000},
#      {'display_name': '/device/udi (part 32 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0032-of-0044.json.zip',
#       'size_mb': '34.86',
#       'records': 100000},
#      {'display_name': '/device/udi (part 33 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0033-of-0044.json.zip',
#       'size_mb': '34.93',
#       'records': 100000},
#      {'display_name': '/device/udi (part 34 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0034-of-0044.json.zip',
#       'size_mb': '34.41',
#       'records': 100000},
#      {'display_name': '/device/udi (part 35 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0035-of-0044.json.zip',
#       'size_mb': '34.46',
#       'records': 100000},
#      {'display_name': '/device/udi (part 36 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0036-of-0044.json.zip',
#       'size_mb': '34.86',
#       'records': 100000},
#      {'display_name': '/device/udi (part 37 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0037-of-0044.json.zip',
#       'size_mb': '34.95',
#       'records': 100000},
#      {'display_name': '/device/udi (part 38 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0038-of-0044.json.zip',
#       'size_mb': '34.74',
#       'records': 100000},
#      {'display_name': '/device/udi (part 39 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0039-of-0044.json.zip',
#       'size_mb': '34.35',
#       'records': 100000},
#      {'display_name': '/device/udi (part 40 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0040-of-0044.json.zip',
#       'size_mb': '34.86',
#       'records': 100000},
#      {'display_name': '/device/udi (part 41 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0041-of-0044.json.zip',
#       'size_mb': '35.04',
#       'records': 100000},
#      {'display_name': '/device/udi (part 42 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0042-of-0044.json.zip',
#       'size_mb': '34.19',
#       'records': 100000},
#      {'display_name': '/device/udi (part 43 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0043-of-0044.json.zip',
#       'size_mb': '34.71',
#       'records': 100000},
#      {'display_name': '/device/udi (part 44 of 44)',
#       'file': 'https://download.open.fda.gov/device/udi/device-udi-0044-of-0044.json.zip',
#       'size_mb': '2.28',
#       'records': 6508}],
#     'total_records': 4306508},
#    'event': {'export_date': '2025-04-28',
#     'partitions': [{'display_name': '2004 Q3 (all)',
#       'file': 'https://download.open.fda.gov/device/event/2004q3/device-event-0001-of-0001.json.zip',
#       'size_mb': '11.10',
#       'records': 21104},
#      {'display_name': '1994 Q4 (all)',
#       'file': 'https://download.open.fda.gov/device/event/1994q4/device-event-0001-of-0001.json.zip',
#       'size_mb': '0.86',
#       'records': 2079},
#      {'display_name': '1997 Q3 (all)',
#       'file': 'https://download.open.fda.gov/device/event/1997q3/device-event-0001-of-0001.json.zip',
#       'size_mb': '8.75',
#       'records': 19917},
#      {'display_name': '2020 Q3 (part 1 of 4)',
#       'file': 'https://download.open.fda.gov/device/event/2020q3/device-event-0001-of-0004.json.zip',
#       'size_mb': '77.96',
#       'records': 100000},
#      {'display_name': '2020 Q3 (part 2 of 4)',
#       'file': 'https://download.open.fda.gov/device/event/2020q3/device-event-0002-of-0004.json.zip',
#       'size_mb': '78.40',
#       'records': 100000},
#      {'display_name': '2020 Q3 (part 3 of 4)',
#       'file': 'https://download.open.fda.gov/device/event/2020q3/device-event-0003-of-0004.json.zip',
#       'size_mb': '75.70',
#       'records': 100000},
#      {'display_name': '2020 Q3 (part 4 of 4)',
#       'file': 'https://download.open.fda.gov/device/event/2020q3/device-event-0004-of-0004.json.zip',
#       'size_mb': '70.31',
#       'records': 94710},
# ...
#       'file': 'https://download.open.fda.gov/drug/event/2016q1/drug-event-0021-of-0028.json.zip',
#       'size_mb': '122.52',
#       'records': 12000},
#      {'display_name': '2016 Q1 (part 22 of 28)',
#       'file': 'https://download.open.fda.gov/drug/event/2016q1/drug-event-0022-of-0028.json.zip',
#       'size_mb': '119.01',
#       'records': 12000},
#      {'display_name': '2016 Q1 (part 23 of 28)',
#       'file': 'https://download.open.fda.gov/drug/event/2016q1/drug-event-0023-of-0028.json.zip',
#       'size_mb': '114.14',
#       'records': 12000},
#      {'display_name': '2016 Q1 (part 24 of 28)',
#       'file': 'https://download.open.fda.gov/drug/event/2016q1/drug-event-0024-of-0028.json.zip',
#       'size_mb': '131.18',
#       'records': 12000},
#      {'display_name': '2016 Q1 (part 25 of 28)',
#       'file': 'https://download.open.fda.gov/drug/event/2016q1/drug-event-0025-of-0028.json.zip',
#       'size_mb': '123.07',
#       'records': 12000},
#      {'display_name': '2016 Q1 (part 26 of 28)',
#       'file': 'https://download.open.fda.gov/drug/event/2016q1/drug-event-0026-of-0028.json.zip',
#       'size_mb': '118.88',
#       'records': 12000},
#      {'display_name': '2016 Q1 (part 27 of 28)',
#       'file': 'https://download.open.fda.gov/drug/event/2016q1/drug-event-0027-of-0028.json.zip',
#       'size_mb': '119.40',
#       'records': 12000},
#      {'display_name': '2016 Q1 (part 28 of 28)',
#       'file': 'https://download.open.fda.gov/drug/event/2016q1/drug-event-0028-of-0028.json.zip',
#       'size_mb': '104.27',
#       'records': 11698},
#      {'display_name': '2022 Q4 (part 1 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0001-of-0034.json.zip',
#       'size_mb': '50.82',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 2 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0002-of-0034.json.zip',
#       'size_mb': '84.73',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 3 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0003-of-0034.json.zip',
#       'size_mb': '138.81',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 4 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0004-of-0034.json.zip',
#       'size_mb': '18.72',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 5 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0005-of-0034.json.zip',
#       'size_mb': '2.80',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 6 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0006-of-0034.json.zip',
#       'size_mb': '2.66',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 7 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0007-of-0034.json.zip',
#       'size_mb': '4.56',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 8 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0008-of-0034.json.zip',
#       'size_mb': '9.62',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 9 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0009-of-0034.json.zip',
#       'size_mb': '5.93',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 10 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0010-of-0034.json.zip',
#       'size_mb': '2.84',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 11 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0011-of-0034.json.zip',
#       'size_mb': '2.80',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 12 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0012-of-0034.json.zip',
#       'size_mb': '2.74',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 13 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0013-of-0034.json.zip',
#       'size_mb': '11.17',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 14 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0014-of-0034.json.zip',
#       'size_mb': '8.51',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 15 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0015-of-0034.json.zip',
#       'size_mb': '4.68',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 16 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0016-of-0034.json.zip',
#       'size_mb': '9.56',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 17 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0017-of-0034.json.zip',
#       'size_mb': '10.80',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 18 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0018-of-0034.json.zip',
#       'size_mb': '10.75',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 19 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0019-of-0034.json.zip',
#       'size_mb': '16.31',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 20 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0020-of-0034.json.zip',
#       'size_mb': '18.73',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 21 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0021-of-0034.json.zip',
#       'size_mb': '25.96',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 22 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0022-of-0034.json.zip',
#       'size_mb': '26.37',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 23 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0023-of-0034.json.zip',
#       'size_mb': '154.70',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 24 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0024-of-0034.json.zip',
#       'size_mb': '133.10',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 25 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0025-of-0034.json.zip',
#       'size_mb': '153.13',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 26 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0026-of-0034.json.zip',
#       'size_mb': '176.37',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 27 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0027-of-0034.json.zip',
#       'size_mb': '174.89',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 28 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0028-of-0034.json.zip',
#       'size_mb': '175.18',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 29 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0029-of-0034.json.zip',
#       'size_mb': '178.91',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 30 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0030-of-0034.json.zip',
#       'size_mb': '184.96',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 31 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0031-of-0034.json.zip',
#       'size_mb': '184.47',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 32 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0032-of-0034.json.zip',
#       'size_mb': '177.42',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 33 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0033-of-0034.json.zip',
#       'size_mb': '174.06',
#       'records': 12000},
#      {'display_name': '2022 Q4 (part 34 of 34)',
#       'file': 'https://download.open.fda.gov/drug/event/2022q4/drug-event-0034-of-0034.json.zip',
#       'size_mb': '127.41',
#       'records': 8486},
#      {'display_name': '2019 Q1 (part 1 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0001-of-0030.json.zip',
#       'size_mb': '64.65',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 2 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0002-of-0030.json.zip',
#       'size_mb': '55.10',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 3 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0003-of-0030.json.zip',
#       'size_mb': '47.51',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 4 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0004-of-0030.json.zip',
#       'size_mb': '26.98',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 5 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0005-of-0030.json.zip',
#       'size_mb': '2.36',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 6 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0006-of-0030.json.zip',
#       'size_mb': '2.66',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 7 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0007-of-0030.json.zip',
#       'size_mb': '31.39',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 8 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0008-of-0030.json.zip',
#       'size_mb': '59.47',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 9 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0009-of-0030.json.zip',
#       'size_mb': '76.29',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 10 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0010-of-0030.json.zip',
#       'size_mb': '16.51',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 11 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0011-of-0030.json.zip',
#       'size_mb': '4.10',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 12 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0012-of-0030.json.zip',
#       'size_mb': '5.02',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 13 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0013-of-0030.json.zip',
#       'size_mb': '6.19',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 14 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0014-of-0030.json.zip',
#       'size_mb': '8.99',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 15 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0015-of-0030.json.zip',
#       'size_mb': '15.14',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 16 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0016-of-0030.json.zip',
#       'size_mb': '11.80',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 17 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0017-of-0030.json.zip',
#       'size_mb': '12.65',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 18 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0018-of-0030.json.zip',
#       'size_mb': '10.17',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 19 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0019-of-0030.json.zip',
#       'size_mb': '88.23',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 20 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0020-of-0030.json.zip',
#       'size_mb': '130.77',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 21 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0021-of-0030.json.zip',
#       'size_mb': '130.71',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 22 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0022-of-0030.json.zip',
#       'size_mb': '129.66',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 23 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0023-of-0030.json.zip',
#       'size_mb': '118.96',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 24 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0024-of-0030.json.zip',
#       'size_mb': '129.71',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 25 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0025-of-0030.json.zip',
#       'size_mb': '119.22',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 26 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0026-of-0030.json.zip',
#       'size_mb': '130.68',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 27 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0027-of-0030.json.zip',
#       'size_mb': '122.25',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 28 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0028-of-0030.json.zip',
#       'size_mb': '128.81',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 29 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0029-of-0030.json.zip',
#       'size_mb': '119.86',
#       'records': 12000},
#      {'display_name': '2019 Q1 (part 30 of 30)',
#       'file': 'https://download.open.fda.gov/drug/event/2019q1/drug-event-0030-of-0030.json.zip',
#       'size_mb': '15.94',
#       'records': 2425},
#      {'display_name': '2017 Q1 (part 1 of 26)',
#       'file': 'https://download.open.fda.gov/drug/event/2017q1/drug-event-0001-of-0026.json.zip',
#       'size_mb': '9.69',
#       'records': 12000},
#      {'display_name': '2017 Q1 (part 2 of 26)',
#       'file': 'https://download.open.fda.gov/drug/event/2017q1/drug-event-0002-of-0026.json.zip',
#       'size_mb': '3.43',
#       'records': 12000},
#      {'display_name': '2017 Q1 (part 3 of 26)',
#       'file': 'https://download.open.fda.gov/drug/event/2017q1/drug-event-0003-of-0026.json.zip',
#       'size_mb': '61.14',
#       'records': 12000},
#      {'display_name': '2017 Q1 (part 4 of 26)',
#       'file': 'https://download.open.fda.gov/drug/event/2017q1/drug-event-0004-of-0026.json.zip',
#       'size_mb': '61.38',
#       'records': 12000},
#      {'display_name': '2017 Q1 (part 5 of 26)',
#       'file': 'https://download.open.fda.gov/drug/event/2017q1/drug-event-0005-of-0026.json.zip',
#       'size_mb': '6.36',
#       'records': 12000},
#      {'display_name': '2017 Q1 (part 6 of 26)',
#       'file': 'https://download.open.fda.gov/drug/event/2017q1/drug-event-0006-of-0026.json.zip',
#       'size_mb': '2.85',
#       'records': 12000},
#      ...],
#     'total_records': 18700795},
#    'shortages': {'export_date': '2025-05-03',
#     'partitions': [{'display_name': '/drug/shortages data',
#       'file': 'https://download.open.fda.gov/drug/shortages/drug-shortages-0001-of-0001.json.zip',
#       'size_mb': '0.56',
#       'records': 1920}],
#     'total_records': 1920},
#    'ndc': {'export_date': '2025-05-03',
#     'partitions': [{'display_name': '/drug/ndc data',
#       'file': 'https://download.open.fda.gov/drug/ndc/drug-ndc-0001-of-0001.json.zip',
#       'size_mb': '25.98',
#       'records': 132657}],
#     'total_records': 132657}}}}

# %%
def partition_id_by_year_quarter(p):
    return "".join(p.get('display_name').split(" ")[:2])

def partition_id_by_year(p):
    return p.get('display_name').split(" ")[0]

def no_of_parts_in_partition(p):
    return int(p.get('display_name').replace("(", "").replace(")","").split(" ")[-1])

def part_size_mb(p):
    return float(p.get('size_mb'))

def get_total_size(json):
    return round(sum([p.get('size_mb') for p in json.get('partitions')]),2)

def read_json_file(json_path):
    with open(json_path, "r") as f:
        d = json.load(f)
        return d

"""
Function to restructure JSON object to handle batch processing better
"""
def extract_drug_events(data):
    events = data.get('results').get('drug').get('event')
    total_records = events.get('total_records')
    partitions = events.get('partitions')

    # Generate unique partition_id and count set
    partition_ids = {}
    for p in partitions:
        id = partition_id_by_year(p)
        partition_ids[id] = partition_ids.get(id,0) + 1
    
    # Groups partition by partitionid
    results = []
    for item in partition_ids.items():
        id, count = item
        file_list = []
        counter = 0
        tot_size = 0

        for p in partitions:
            if counter == count:
                break
            if partition_id_by_year(p) == id:
                counter+=1
                file_list.append(p.get('file'))
                tot_size+=part_size_mb(p)
                
        results.append(
            {
                "partition_id": id,
                "count": count,
                "size_mb" : round(tot_size,2),
                "files" : file_list
            }
        )
    
    return {
        "total_records" : total_records,
        "partitions" : results
    }

"""
Function to seggregate partitions as batches based on disksize threshold
"""
def create_batch(partitions, max_batch_size_mb=10000):
    batch = []                  # partitions per batch
    batch_partitions = []       # Partitions under the threshold
    big_batch_partitions = []   # Different approach to process bigger partitions
    sum_size = 0                # Size counter

    for p in partitions:
        size = p.get('size_mb', 0)

        if size > max_batch_size_mb:
            # TODO:
            # Handle oversized partititions
            big_batch_partitions.append(p)
            continue
        
        if sum_size + size > max_batch_size_mb:
            # TODO:
            # - Declare batch_partitions as batch #
            # - Reset sum_size
            # - Reset batch_partitions
            batch.append(batch_partitions.copy())
            batch_partitions.clear()
            sum_size = 0
            continue
        
        batch_partitions.append(p)
        sum_size += size

    # Flush batch_partitions to schedule as last batch
    if len(batch_partitions) != 0:
        batch.append(batch_partitions.copy())
        batch_partitions.clear()
    
    return batch, big_batch_partitions

# %%
# Original Count
len([p for p in data.get('results').get('drug').get('event').get('partitions') if p.get('display_name')[:4] == '2023'])
# Out:
# 121

# %%
# Restrcutured JSON
downloads_json = extract_drug_events(data)
downloads_json
# Out:
# {'total_records': 18700795,
#  'partitions': [{'partition_id': '2004',
#    'count': 20,
#    'size_mb': 1034.56,
#    'files': ['https://download.open.fda.gov/drug/event/2004q3/drug-event-0001-of-0005.json.zip',
#     'https://download.open.fda.gov/drug/event/2004q3/drug-event-0002-of-0005.json.zip',
#     'https://download.open.fda.gov/drug/event/2004q3/drug-event-0003-of-0005.json.zip',
#     'https://download.open.fda.gov/drug/event/2004q3/drug-event-0004-of-0005.json.zip',
#     'https://download.open.fda.gov/drug/event/2004q3/drug-event-0005-of-0005.json.zip',
#     'https://download.open.fda.gov/drug/event/2004q2/drug-event-0001-of-0005.json.zip',
#     'https://download.open.fda.gov/drug/event/2004q2/drug-event-0002-of-0005.json.zip',
#     'https://download.open.fda.gov/drug/event/2004q2/drug-event-0003-of-0005.json.zip',
#     'https://download.open.fda.gov/drug/event/2004q2/drug-event-0004-of-0005.json.zip',
#     'https://download.open.fda.gov/drug/event/2004q2/drug-event-0005-of-0005.json.zip',
#     'https://download.open.fda.gov/drug/event/2004q1/drug-event-0001-of-0005.json.zip',
#     'https://download.open.fda.gov/drug/event/2004q1/drug-event-0002-of-0005.json.zip',
#     'https://download.open.fda.gov/drug/event/2004q1/drug-event-0003-of-0005.json.zip',
#     'https://download.open.fda.gov/drug/event/2004q1/drug-event-0004-of-0005.json.zip',
#     'https://download.open.fda.gov/drug/event/2004q1/drug-event-0005-of-0005.json.zip',
#     'https://download.open.fda.gov/drug/event/2004q4/drug-event-0001-of-0005.json.zip',
#     'https://download.open.fda.gov/drug/event/2004q4/drug-event-0002-of-0005.json.zip',
#     'https://download.open.fda.gov/drug/event/2004q4/drug-event-0003-of-0005.json.zip',
#     'https://download.open.fda.gov/drug/event/2004q4/drug-event-0004-of-0005.json.zip',
#     'https://download.open.fda.gov/drug/event/2004q4/drug-event-0005-of-0005.json.zip']},
#   {'partition_id': '2020',
#    'count': 121,
#    'size_mb': 7604.26,
#    'files': ['https://download.open.fda.gov/drug/event/2020q3/drug-event-0001-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2020q3/drug-event-0002-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2020q3/drug-event-0003-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2020q3/drug-event-0004-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2020q3/drug-event-0005-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2020q3/drug-event-0006-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2020q3/drug-event-0007-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2020q3/drug-event-0008-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2020q3/drug-event-0009-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2020q3/drug-event-0010-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2020q3/drug-event-0011-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2020q3/drug-event-0012-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2020q3/drug-event-0013-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2020q3/drug-event-
of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2019q4/drug-event-0014-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2019q4/drug-event-0015-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2019q4/drug-event-0016-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2019q4/drug-event-0017-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2019q4/drug-event-0018-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2019q4/drug-event-0019-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2019q4/drug-event-0020-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2019q4/drug-event-0021-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2019q4/drug-event-0022-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2019q4/drug-event-0023-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2019q4/drug-event-0024-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2019q4/drug-event-0025-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2019q4/drug-event-0026-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2019q4/drug-event-0027-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2019q4/drug-event-0028-of-0029.json.zip',
#     'https://download.open.fda.gov/drug/event/2019q4/drug-event-0029-of-0029.json.zip']}]}

# %%
partitions = downloads_json.get('partitions')
sorted([(p.get('partition_id'), len(p.get('files'))) for p in partitions])
# Out:
# [('2004', 20),
#  ('2005', 21),
#  ('2006', 21),
#  ('2007', 27),
#  ('2008', 30),
#  ('2009', 32),
#  ('2010', 38),
#  ('2011', 46),
#  ('2012', 47),
#  ('2013', 66),
#  ('2014', 70),
#  ('2015', 104),
#  ('2016', 97),
#  ('2017', 102),
#  ('2018', 120),
#  ('2019', 121),
#  ('2020', 121),
#  ('2021', 134),
#  ('2022', 131),
#  ('2023', 121),
#  ('2024', 127),
#  ('All', 4)]

# %%
def filter_partition(years='',):
    years = [y.strip() for y in years.split(",")]
    if not years:
        print("No args provided")
        return
    return [p for p in downloads_json.get('partitions') if p.get('partition_id') in years]

filter_partition('2004,2005,2006')
# Out:
# [{'partition_id': '2004',
#   'count': 20,
#   'size_mb': 1034.56,
#   'files': ['https://download.open.fda.gov/drug/event/2004q3/drug-event-0001-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2004q3/drug-event-0002-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2004q3/drug-event-0003-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2004q3/drug-event-0004-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2004q3/drug-event-0005-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2004q2/drug-event-0001-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2004q2/drug-event-0002-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2004q2/drug-event-0003-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2004q2/drug-event-0004-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2004q2/drug-event-0005-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2004q1/drug-event-0001-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2004q1/drug-event-0002-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2004q1/drug-event-0003-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2004q1/drug-event-0004-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2004q1/drug-event-0005-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2004q4/drug-event-0001-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2004q4/drug-event-0002-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2004q4/drug-event-0003-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2004q4/drug-event-0004-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2004q4/drug-event-0005-of-0005.json.zip']},
#  {'partition_id': '2005',
#   'count': 21,
#   'size_mb': 1216.43,
#   'files': ['https://download.open.fda.gov/drug/event/2005q2/drug-event-0001-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2005q2/drug-event-0002-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2005q2/drug-event-0003-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2005q2/drug-event-0004-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2005q2/drug-event-0005-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2005q4/drug-event-0001-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2005q4/drug-event-0002-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2005q4/drug-event-0003-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2005q4/drug-event-0004-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2005q4/drug-event-0005-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2005q1/drug-event-0001-of-0006.json.zip',
#    'https://download.open.fda.gov/drug/event/2005q1/drug-event-0002-of-0006.json.zip',
#    'https://download.open.fda.gov/drug/event/2005q1/drug-event-0003-of-0006.json.zip',
#    'https://download.open.fda.gov/drug/event/2005q1/drug-event-0004-of-0006.json.zip',
#    'https://download.open.fda.gov/drug/event/2005q1/drug-event-0005-of-0006.json.zip',
#    'https://download.open.fda.gov/drug/event/2005q1/drug-event-0006-of-0006.json.zip',
#    'https://download.open.fda.gov/drug/event/2005q3/drug-event-0001-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2005q3/drug-event-0002-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2005q3/drug-event-0003-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2005q3/drug-event-0004-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2005q3/drug-event-0005-of-0005.json.zip']},
#  {'partition_id': '2006',
#   'count': 21,
#   'size_mb': 1105.64,
#   'files': ['https://download.open.fda.gov/drug/event/2006q1/drug-event-0001-of-0006.json.zip',
#    'https://download.open.fda.gov/drug/event/2006q1/drug-event-0002-of-0006.json.zip',
#    'https://download.open.fda.gov/drug/event/2006q1/drug-event-0003-of-0006.json.zip',
#    'https://download.open.fda.gov/drug/event/2006q1/drug-event-0004-of-0006.json.zip',
#    'https://download.open.fda.gov/drug/event/2006q1/drug-event-0005-of-0006.json.zip',
#    'https://download.open.fda.gov/drug/event/2006q1/drug-event-0006-of-0006.json.zip',
#    'https://download.open.fda.gov/drug/event/2006q2/drug-event-0001-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2006q2/drug-event-0002-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2006q2/drug-event-0003-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2006q2/drug-event-0004-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2006q2/drug-event-0005-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2006q4/drug-event-0001-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2006q4/drug-event-0002-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2006q4/drug-event-0003-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2006q4/drug-event-0004-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2006q4/drug-event-0005-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2006q3/drug-event-0001-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2006q3/drug-event-0002-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2006q3/drug-event-0003-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2006q3/drug-event-0004-of-0005.json.zip',
#    'https://download.open.fda.gov/drug/event/2006q3/drug-event-0005-of-0005.json.zip']}]

# %%
# Create batches
partitions = downloads_json.get('partitions')
batch, _ = create_batch(partitions, max_batch_size_mb=13000)
print(len(batch))
print(len(_))
# Out:
# 6
# 0

# %%
logger = get_module_logger(__name__)

class ADE:
    # Patient information
    patient_header = [
        "patientid",
        "patientagegroup",
        "patientonsetage",
        "patientonsetageunit",
        "patientsex",
        "patientweight",
        "serious",
        "seriousnessdeath",
        "seriousnesshospitalization",
        "seriousnessdisabling",
        "seriousnesslifethreatening",
        "seriousnessother",
        "receivedate",
        "receiptdate",
        "safetyreportid"
    ]

    # Drug information
    drug_header = [
        "patientid",
        "medicinalproduct",
        "activesubstancename",
        "drugindication",
        "drugadministrationroute",
        "drugstartdate",
        "drugenddate",
        "drugdosagetext",
        "drugstructuredosagenumb",
        "drugstructuredosageunit",
        "drugtreatmentduration",
        "drugtreatmentdurationunit",
        "drugrecurreadministration",
    ]

    # Reaction information
    reaction_header = [
        "patientid",
        "reactionmeddrapt",
        "reactionoutcome",
    ]

    def __init__(self):
        self.patients_list = []
        self.drugs_list = []
        self.reactions_list = []
    
    def extractJSON(self, data):
        for item in data:
            patientid = str(uuid.uuid4())
            patient = item.get("patient",{})

            self.patients_list.append((
                patientid,
                patient.get("patientagegroup"),
                patient.get("patientonsetage"),
                patient.get("patientonsetageunit"),
                patient.get("patientsex"),
                patient.get("patientweight"),
                patient.get("serious"),
                patient.get("seriousnessdeath"),
                patient.get("seriousnesshospitalization"),
                patient.get("seriousnessdisabling"),
                patient.get("seriousnesslifethreatening"),
                patient.get("seriousnessother"),
                patient.get("receivedate"),
                patient.get("receiptdate"),
                patient.get("safetyreportid"),
            ))

            drugs = patient.get('drug',[])
            for drug in drugs:
                self.drugs_list.append((
                    patientid,
                    drug.get("medicinalproduct"),
                    drug.get("activesubstance",{}).get("activesubstancename"),
                    drug.get("drugindication"),    
                    drug.get("drugadministrationroute"),    
                    drug.get("drugstartdate"),
                    drug.get("drugenddate"),
                    drug.get("drugdosagetext"),
                    drug.get("drugstructuredosagenumb"),
                    drug.get("drugstructuredosageunit"),
                    drug.get("drugtreatmentduration"),
                    drug.get("drugtreatmentdurationunit"),
                    drug.get("drugrecurreadministration"),
                ))

            reactions = patient.get("reaction",[])
            for reaction in reactions:
                self.reactions_list.append((
                    patientid,
                    reaction.get("reactionmeddrapt"),
                    reaction.get("reactionoutcome"),
                ))

    def _to_dataframe(self):
        df_patients = pd.DataFrame(self.patients_list, columns=self.patient_header)
        df_drugs = pd.DataFrame(self.drugs_list, columns=self.drug_header)
        df_reactions = pd.DataFrame(self.reactions_list, columns=self.reaction_header)

        return df_patients, df_drugs, df_reactions

    def save_as_parquet(self, fname, dir):
        df_patients, df_drugs, df_reactions = self._to_dataframe()
        df = [df_patients, df_drugs, df_reactions]

        dirs = []

        for p in ["patient", "drug", "reaction"]:
            # ./pq/patient/yr/
            path = os.path.join("pq", p, dir)
            dirs.append(path)
            os.makedirs(path, exist_ok=True)
        
        for d,p in zip(df, dirs):
            saved_path = os.path.join(p,f"{fname}.parquet")
            d.to_parquet(saved_path)
            logger.info(f"Parquet File saved to: {saved_path}")

# %%
# def download_file(url, download_path="tmp", filename="temp.json"):
#     os.makedirs(download_path,exist_ok=True)
#     subprocess.run(
#         f'wget -q -O - {shlex.quote(url)} | gunzip > {shlex.quote(os.path.join(download_path,filename))}',
#         shell=True,
#     )

# download_file(
#     url=downloads_json['partitions'][1].get('files')[0],
# )

# %%
# b = batch[1]
# p = b[0]
# url = p.get('files')[0]
# url

# %%
# ade = ADE()
# data = read_json_file("./tmp/temp.json")['results']
# ade.extractJSON(data)
# ade.save_as_parquet(url, return_dirs=True)
# # dirs = ade.save_as_parquet(url, return_dirs=True)
# # dirs

# %%
# # local_base_path = "tmp" # relative to this path, that's why rel_path displays "../" because it needs to go one level up to go into pq
# local_base_path = "pq"
# gcs_base_path = "data/pq"
# for r,d,f in os.walk(dirs[0]):
#     # print(r)
#     # print(f)
#     for F in f:
#         local_file_path = os.path.join(r,F)
#         print(local_file_path)

#         rel_path = os.path.relpath(local_file_path, local_base_path) # this path is relative to "pq" so it only displays the directory relative to it
#         gcs_path = os.path.join(gcs_base_path, rel_path).replace("\\","/")
#         # print(rel_path)
#         print(gcs_path)

# %%
from google.cloud import storage

def upload_to_gcs(local_base_dir, bucket_name, gcs_prefix):
    client = storage.Client()
    bucket = client.bucket(bucket_name)

    for root, _, files in os.walk(local_base_dir):
        for file in files:
            if file.endswith(".parquet"):
                local_file_path = os.path.join(root, file)
                
                # Relative path from the local_base_dir
                relative_path = os.path.relpath(local_file_path, local_base_dir)
                gcs_blob_path = os.path.join(gcs_prefix, relative_path).replace("\\", "/")
                blob = bucket.blob(gcs_blob_path)
                blob.upload_from_filename(local_file_path)
                
                logger.info(f"Uploaded {local_file_path} to gs://{bucket_name}/{gcs_blob_path}")

# %%
def process_batch(batch):

    # Directories of temporary files and folder
    tmp_dirs = ["./raw", "./pq"]

    # Create temporary directories
    if not os.path.exists(tmp_dirs[0]):
        logger.info("Directory 'raw' missing. Created 'raw'")
        os.makedirs(tmp_dirs[0],exist_ok=True)

    # Insert batch iteration here
    for i, b in enumerate(batch):
        logger.info('===================================================================')
        logger.info(f'============================= BATCH {i+1} =============================')
        logger.info('===================================================================')

        # Insert partition iteration here
        for j,p in enumerate(b):
            logger.info(f'----------------- Processing partition {j+1} -----------------')  

            files = p.get('files')
            total_count = p.get('count')
            file_count = 1
            for f in files:
                dl_filename = f"drug-event-part-{file_count}-of-{total_count}"
                try:
                    # Download and unzip
                    logger.info(f"Download started: {f}")

                    dl_filepath = os.path.join(tmp_dirs[0],f"{dl_filename}.json")  
                    result = subprocess.run(
                        f'wget -q -O - {shlex.quote(f)} | gunzip > {shlex.quote(dl_filepath)}',
                        shell=True,
                        check=True,
                        capture_output=True,
                        text=True
                    )

                    # Saved to tmp folder
                    logger.info(f"Filed saved to: {dl_filepath}")

                    # Load JSON and map to class ADE
                    ade = ADE()
                    temp_json = read_json_file(dl_filepath)['results']
                    ade.extractJSON(temp_json)
                    logger.info(f"Parsed json file to ADE object: {dl_filepath}")


                    # Save ADE object as parquet file
                    ade.save_as_parquet(fname=dl_filename, dir=p.get('partition_id'))

                    # Upload parquet file to GCS bucket
                    upload_to_gcs(local_base_dir="pq",bucket_name='ade-pipeline',gcs_prefix="data/pq")

                    # Increment part number
                    file_count+=1

                except subprocess.CalledProcessError as e:
                    logger.error(f"(return {e.returncode}) Failed to download or unzip: {f}")
                    logger.error(f"{e.stderr.strip()}")
                except Exception as e:
                    logger.error(f"Unexpected error occured: {e}")

            # Purge tmp folder to prepare for next partition
            for dir_path in tmp_dirs:
                wildcard_path = os.path.join(dir_path, "*")
                quoted_path = shlex.quote(dir_path)
                subprocess.run(f"rm -rf {quoted_path}", shell=True, check=True)
            logging.info("Purged tmp directories")

        logger.info('===================================================================')
        logger.info('============================= Batch {i} END =========================')
        logger.info('===================================================================')
    
    # Summary of the batch script
    # Total batch processed
    # Size of each batch processed
    # Etc
    logger.info("Batch Processing Completed!")

# %%
# process_batch(batch[2:4])

# %%
# tmp_dirs = ["./raw", "./pq"]

# # Purge tmp folder to prepare for next partition
# for dir_path in tmp_dirs:
#     wildcard_path = os.path.join(dir_path, "*")
#     quoted_path = shlex.quote(dir_path)
#     subprocess.run(f"rm -rf {quoted_path}", shell=True, check=True)

# %%
temp_path = "temp"
os.makedirs(temp_path,exist_ok=True)
for i in range(5):
    fname=f"test-{i+1}.txt"
    fpath=os.path.join(temp_path,fname)
    subprocess.run(f"touch {fpath}",shell=True)

# %%
del_path = os.path.join(temp_path,"*")
result = subprocess.Popen(f"rm -rfv {del_path}",shell=True, stdout=subprocess.PIPE, text=True)

# Purging temp directory
for o in result.stdout:
    logger.info(o.strip())
# Out:
# [2025-04-18 16:59:15,906] __main__:6 - INFO - removed 'temp/test-1.txt'
# [2025-04-18 16:59:15,908] __main__:6 - INFO - removed 'temp/test-2.txt'
# [2025-04-18 16:59:15,908] __main__:6 - INFO - removed 'temp/test-3.txt'
# [2025-04-18 16:59:15,909] __main__:6 - INFO - removed 'temp/test-4.txt'
# [2025-04-18 16:59:15,910] __main__:6 - INFO - removed 'temp/test-5.txt'
